# %%
import pandas as pd

# %% [markdown]
# ## Function to Import URL Links

# %%
def import_url(url_lst,year_tuple)    :
    '''Function to import multiple URL in a single dataframe and add a column
    corresponding to the year
    parameters:
        url_lst = list of url adresses
        year_tuple = tuple of the year to add in the column '''

    i=0
    df_final = pd.DataFrame()

    for year in range(year_tuple[0],year_tuple[1]):
        # Remplacez 'lien_annee' par le lien spécifique pour chaque année
        url = url_lst[i]

        # Utilisez pd.read_html() pour importer la table à partir du lien
        tables = pd.read_html(url, encoding='utf-8')

        # Sélectionnez la table appropriée (peut nécessiter un examen préalable)
        df = tables[0]

        # Ajoutez une colonne 'year' avec l'année correspondante
        df['year'] = year

        # Ajoutez le DataFrame à la liste
        df_final = pd.concat([df_final, df], ignore_index=True)
        i+=1

    return df_final

# %% [markdown]
# # Importation C-Section/Delivery/Kidney

# %% [markdown]
# Definition of the period and URL list for each kind of data

# %%
year_tuple = (2015, 2022)

# G.1.4.P   Césariennes
url_c_section = ['https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE1.html',
                 'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE2.html',
                 'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE3.html',
                 'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE4.html',
                 'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE5.html',
                 'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDIw.html',
                 'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDIx.html']

# L.5.1.F   Total des transplantations rénales
url_kidney = ["https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE1.html",
              "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE2.html",
              "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE3.html",
              "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE4.html",
              "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE5.html",
              "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDIw.html",
              "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDIx.html"]

# G.1.1.F   Accouchements hospitaliers
url_delivery = ["https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE1.html",
                "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE2.html",
                "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE3.html",
                "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE4.html",
                "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE5.html",
                "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDIw.html",
                "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDIx.html"]

# %% [markdown]
# Use of the function "import_url" for each data

# %%
df_cesarienne = import_url(url_c_section, year_tuple)
kidney = import_url(url_kidney, year_tuple)
accouchement = import_url(url_delivery, year_tuple)

#adding the missing data for C-Sections in the Hirslanden Klinik for 2015
hirslanden_2015 = {'hôpital': 'Klinik Hirslanden AG', 'canton': 'ZH', 'nombre de cas': 627, 'year': 2015}
df_cesarienne = df_cesarienne.append(hirslanden_2015, ignore_index=True)

print(df_cesarienne[df_cesarienne['hôpital']=='Klinik Hirslanden AG'])
# Out:
#                   hôpital canton nombre de cas  year
# 103  Klinik Hirslanden AG     ZH           539  2016
# 191  Klinik Hirslanden AG     ZH           539  2017
# 278  Klinik Hirslanden AG     ZH           497  2018
# 367  Klinik Hirslanden AG     ZH           478  2019
# 449  Klinik Hirslanden AG     ZH           507  2020
# 532  Klinik Hirslanden AG     ZH           604  2021
# 601  Klinik Hirslanden AG     ZH           627  2015
# <ipython-input-4-2d085935b212>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_cesarienne = df_cesarienne.append(hirslanden_2015, ignore_index=True)

# %% [markdown]
# Cleaning and merging of the Dataframes

# %%
#Rename the columns of the dataframes
kidney.rename(columns={'hôpital': 'hospital', 'nombre de cas':'cases_kidney'}, inplace=True)
df_cesarienne.rename(columns={'hôpital': 'hospital', 'nombre de cas':'cases_c-section'}, inplace=True)
accouchement.rename(columns={'hôpital': 'hospital', 'nombre de cas':'delivery'}, inplace=True)

#Merger les df en fonction de year, hospital et canton
df_global = accouchement.merge(df_cesarienne, on=['year', 'hospital','canton'], how='left')
df_global = df_global.merge(kidney, on=['year', 'hospital','canton'], how='left')
df_global = df_global[df_global['canton'] != 'canton']

# %%
na_count = df_global.isna().sum()
print(na_count)
# Out:
# hospital             0
# canton               0
# delivery             0
# year                 0
# cases_c-section    108
# cases_kidney       658
# dtype: int64

# %%
df_global
# Out:
#                                               hospital canton delivery  year  \
# 0            Les Hôpitaux Universitaires de Genève HUG     GE    4 048  2015
# 1                               LUKS Spitalbetriebe AG     LU    2 988  2015
# 2        CHUV Centre Hospitalier Universitaire Vaudois     VD    2 909  2015
# 3                            Universitätsspital Zürich     ZH    2 839  2015
# 4                             Universitätsspital Basel     BS    2 509  2015
# ..                                                 ...    ...      ...   ...
# 703                           Geburtshaus Tagmond GmbH     BL       43  2021
# 704  Center da Sanda Engiadina Bassa Ospidal d'Engi...     GR       41  2021
# 705                   Maison de naissance Les Cigognes     JU       35  2021
# 706                     Maison de Naissance Tilia Sàrl     NE       32  2021
# 707                           Asana Spital Menziken AG     AG        1  2021
#
#     cases_c-section cases_kidney
# ...

# %% [markdown]
# Add a column if the Canton is Swiss german or Latin and the same for university

# %%
#Définition des cantons Latins
Canton_RO = ['GE','VD','NE','JU','FR','VS','TI']

#Définition des hopitaux universitaires
nom_hopitaux = ['Les Hôpitaux Universitaires de Genève HUG',
                'CHUV Centre Hospitalier Universitaire Vaudois',
                'Inselspital Bern','Insel Gruppe AG (universitär)',
                'Universitätsspital Zürich',
                'Universitätsspital Basel',
               'UniversitÃ¤tsspital ZÃ¼rich',
               'CHUV Centre Hospitalier Universitaire Vaudois',
               'UniversitÃ¤tsspital Basel',
                'Les HÃ´pitaux Universitaires de GenÃ¨ve HUG',
                'Insel Gruppe AG (universitÃ¤r)']

#Ajout de variable pour définir si canton latin/allémanique et hôpital universitaire
df_global['Reg'] = df_global['canton'].apply(lambda x: 'RO' if x in Canton_RO else 'AL')
df_global['Uni'] = df_global['hospital'].apply(lambda x: 1 if x in nom_hopitaux else 0)

# %% [markdown]
# Cleaning up numbers with a space after thousands and adding a column with the percentage of c-section

# %%
#Conversion des valeurs string en int
df_global['delivery'] = df_global['delivery'].apply(lambda x: x.replace('\xa0', ''))
df_global['delivery'] = pd.to_numeric(df_global['delivery'], errors='coerce')

df_global['cases_c-section'] = df_global['cases_c-section'].apply(lambda x: x.replace('\xa0', '') if isinstance(x, str) else x)
df_global['cases_c-section'] = pd.to_numeric(df_global['cases_c-section'], errors='coerce')

df_global['cases_kidney'] = df_global['cases_kidney'].apply(lambda x: x.replace('\xa0', '') if isinstance(x, str) else x)
df_global['cases_kidney'] = pd.to_numeric(df_global['cases_kidney'], errors='coerce')

#Ajout d'une ligne pour le pourcenatage de C-Section
df_global['percentage_c-section'] = df_global['cases_c-section']/df_global['delivery']

# %% [markdown]
# Data cleaning: delete "maison de naissance" and "Geburtshaus" beceause by definition there is no c-section in these "hospitals"

# %%
# Get the unique name of the hospital (as a check)
df_global["hospital"].unique()
# Out:
# array(['Les Hôpitaux Universitaires de Genève HUG',
#        'LUKS Spitalbetriebe AG',
#        'CHUV Centre Hospitalier Universitaire Vaudois',
#        'Universitätsspital Zürich', 'Universitätsspital Basel',
#        'Spital Thurgau AG Kantonsspitäler Frauenfeld & Münsterlingen',
#        'Lindenhofgruppe AG', 'Hôpital Riviera-Chablais Vaud-Valais',
#        'Stadtspital Triemli', 'EOC Ente ospedaliero cantonale',
#        'Spital Zollikerberg', 'Kantonsspital Winterthur',
#        'Hôpital du Valais - Centre hospitalier du centre du Valais (CHCVs)',
#        'Insel Gruppe AG (universitär)', 'Kantonsspital St. Gallen',
#        'Kantonsspital Aarau AG', 'Kantonsspital Baden AG',
#        'Réseau hospitalier neuchâtelois RHNe', 'Hôpital Jules Daler',
#        'Spital Bülach AG', 'Spitalverbund Appenzell Ausserrhoden',
#        'Solothurner Spitäler AG', 'EHC Ensemble hospitalier de la Côte',
#        'Bethesda Spital AG', 'Kantonsspital Baselland',
# ...

# %%
# Identify the hospitals that will be deleted
import re
def_hosp=df_global[['hospital']]

# Utilisation de la méthode str.contains avec une expression régulière pour filtrer les lignes
to_delete = def_hosp[def_hosp['hospital'].str.contains(r'\b\w*(naissance|Geburtshaus|Geburtshus)\w*\b', case=False, regex=True)]

# Create a list
to_delete = to_delete.values.tolist()
to_delete

to_delete = [item for sublist in to_delete for item in sublist]
to_delete
# Out:
# <ipython-input-15-fff667bf65df>:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   to_delete = def_hosp[def_hosp['hospital'].str.contains(r'\b\w*(naissance|Geburtshaus|Geburtshus)\w*\b', case=False, regex=True)]
# ['Geburtshaus Zürcher Oberland AG',
#  'Geburtshaus Terra Alta',
#  'Geburtshaus Delphys',
#  'Geburtshus Storchenäscht AG',
#  'Geburtshaus Luna AG',
#  'Maison de Naissance le Petit Prince',
#  'Maison de naissance La Roseraie',
#  'Geburtshaus Stans',
#  'Geburtshaus ambra GmbH',
#  'Maison de Naissance Tilia Sàrl',
#  'Geburtshaus Tagmond GmbH',
#  'Maison de naissance Les Cigognes',
#  'Ita Wegman Geburtshaus',
#  'Geburtshaus Basel',
#  'Geburtshaus Zürcher Oberland AG',
#  'Geburtshaus Terra Alta',
#  'Geburtshaus Delphys',
#  'Geburtshaus Luna AG',
#  'Geburtshus Storchenäscht AG',
#  'Maison de Naissance le Petit Prince',
#  'Geburtshaus Stans',
# ...

# %%
len(to_delete)
# Out:
# 101

# %%
# Identify the hospitals that will be deleted in our dataset (new variable in the dataset)
df_global['to_delete'] = df_global['hospital'].apply(lambda x: '1' if x in to_delete else '0')

# %%
# Create a new dataset without the "maison de naissances" and "Geburtshaus"
df_global_2 = df_global[df_global['to_delete'] == '0']

# %%
# Additional check: are there hospitals without c-section?

test=df_global_2[df_global_2['cases_c-section'].isna()]
print(test)
# Question: shall we keep them??? I would say no...
df_global_3=df_global_2[df_global_2['cases_c-section'].notna()]


df_global_2.to_csv('hospital_cases_v2.csv', index=False) # without the maison de naissance but with NA in c-section
df_global_3.to_csv('hospital_cases_v3.csv', index=False) # without the maison de naissance and without NA in c-section
# Out:
#                                               hospital canton  delivery  year  \
# 102  Swiss Medical Network Hospitals SA Clinique Gé...     FR         1  2015
# 204                        Pôle santé du Pays-d'Enhaut     VD         1  2016
# 409                         Nouvelle Clinique Vert-Pré     GE         1  2018
# 510                      Center da Sanadad Savognin SA     GR         1  2019
# 511                                Clinique la Colline     GE         1  2019
# 610                                 Spital Zofingen AG     AG         1  2020
# 707                           Asana Spital Menziken AG     AG         1  2021
#
#      cases_c-section  cases_kidney Reg  Uni  percentage_c-section to_delete
# 102              NaN           NaN  RO    0                   NaN         0
# 204              NaN           NaN  RO    0                   NaN         0
# 409              NaN           NaN  RO    0                   NaN         0
# ...

# %%
df_global = df_global_3

# %% [markdown]
# # Importation of the hopsitals Data

# %%
url = "https://spitalstatistik.bagapps.ch/data/download/kzp21_KZ_TimeSerie.xlsx?v=1678279041"
sheet = 'KZ2008-KZ2021'
df_hopitaux_0 = pd.read_excel(url, sheet_name=sheet)

# %% [markdown]
# Deletion of data prior to 2015

# %%
df_hopitaux_0 = df_hopitaux_0[df_hopitaux_0['JAHR']>2014]

# %%
column_names=df_hopitaux_0.columns.tolist()
print(column_names)
df_hopitaux_0.head()
# Out:
# ['JAHR', 'KT', 'Status', 'Inst', 'Adr', 'Ort', 'Typ', 'Notfalldienst', 'Infrastruktur1', 'Infrastruktur2', 'Infrastruktur3', 'Infrastruktur4', 'RWStatus', 'Akt', 'SL', 'WB', 'AnzStand', 'SA', 'RForm', 'LA', 'AmbKonsT', 'Ptage', 'PtageStatT', 'PtageStatMST', 'Aust', 'AustStatT', 'AustStatMST', 'Neug', 'NeugStatT', 'NeugStatMST', 'pAkutPT', 'Ops', 'Gebs', 'CMIb', 'CMIn', 'pAuPat', 'pPatWAU', 'pAkPat', 'pPatWAK', 'pZusVers', 'pPatLKP', 'pPatHOK', 'TeilsP', 'Leist', 'FMHKat', 'PersA', 'PersAWB', 'PersP', 'PersMT', 'PersS', 'PersT', 'StdBelA', 'StdBelP', 'PersAFall', 'PersPFall', 'PersMTFall', 'PersSFall', 'PersTFall', 'PersAFallMS', 'PersPFallMS', 'PersMTFallMS', 'PersTFallMS', 'AnzBelA', 'AnzBelP (nur ab KZP2010)', 'pMRI_AMB', 'pMRI_STAT', 'pCT_AMB', 'pCT_STAT', 'pANGIO_AMB', 'pANGIO_STAT', 'pDIA_AMB', 'pDIA_STAT', 'AwBesold', 'AwInvest', 'AwSonst', 'AwT', 'EtMedL', 'EtSonst', 'EtSubv', 'EtDef', 'FiErg', 'EtAmb', 'AmbKonsA', 'PtageStatA', 'PtageStatMSA', 'AustStatA', 'AustStatMSA', 'Bet
# ...

# %% [markdown]
# Rename columns and process column with private percentage

# %%
df_hopitaux = df_hopitaux_0[['JAHR','KT','Inst','PersA','PersAWB','PersP','PersMT','PersT','Ops','Gebs','pPatLKP','BettenStatA']]

df_hopitaux['Inst'] = df_hopitaux['Inst'].replace('Inselspital Bern', 'Insel Gruppe AG (universitär)')

columns = ['JAHR','KT','Inst','Doctor','Doctor_in_formation','Nurse','Other_Nurse','Total_staff','Operation_rooms','Delivery_rooms','Private_division', 'Beds']

df_hopitaux.columns = columns

df_hopitaux.rename(columns={'Inst': 'hospital', 'JAHR':'year', 'KT':'canton'}, inplace=True)

# Use a lambda function to conditionally divide values by 100 if greater than one
# (The calculation has changed between 2015 and 2021)
df_hopitaux['Private_division'] = df_hopitaux['Private_division'].apply(lambda x: x / 100 if x > 1 else x)
# Out:
# <ipython-input-20-6d48d61c2bf5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hopitaux['Inst'] = df_hopitaux['Inst'].replace('Inselspital Bern', 'Insel Gruppe AG (universitär)')
# <ipython-input-20-6d48d61c2bf5>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hopitaux.rename(columns={'Inst': 'hospital', 'JAHR':'year', 'KT':'canton'}, inplace=True)
# <ipython-input-20-6d48d61c2bf5>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_hopitaux
# Out:
#       year canton                                           hospital  Doctor  \
# 2108  2015     AG                             Kantonsspital Aarau AG  587.71
# 2109  2015     AG                             Kantonsspital Baden AG  290.71
# 2110  2015     AG                            Hirslanden Klinik Aarau   12.25
# 2111  2015     AG                        Gesundheitszentrum Fricktal   82.90
# 2112  2015     AG                        Kreisspital für das Freiamt   74.27
# ...    ...    ...                                                ...     ...
# 4069  2021     ZH                                Geburtshaus Delphys    0.00
# 4070  2021     ZH  Universitäts-Kinderspital Zürich - Das Spital ...  338.31
# 4071  2021     ZH                                    Klinik Lengg AG   27.64
# 4072  2021     ZH                                   Klinik Susenberg    7.07
# 4073  2021     ZH                                          Sune-Egge    5.10
#
# ...

# %% [markdown]
# # Merging of the two dataframes and exportation

# %%
df_global = df_global.merge(df_hopitaux, on=['year', 'hospital', 'canton'], how='left')

# %% [markdown]
# Looking at the data

# %%
na_per_variable = df_global.isna().sum()
print(na_per_variable)
# It looks like there is like 98 lines that have no doctors, nor beds. We need to investigate. We'll delete the rows that have missing values for beds

df_global = df_global.dropna(subset=['Beds'])
# Out:
# hospital                  0
# canton                    0
# delivery                  0
# year                      0
# cases_c-section           0
# cases_kidney            550
# Reg                       0
# Uni                       0
# percentage_c-section      0
# to_delete                 0
# Doctor                   98
# Doctor_in_formation     364
# Nurse                    98
# Other_Nurse              98
# Total_staff              98
# Operation_rooms          98
# Delivery_rooms           98
# Private_division         97
# Beds                     98
# dtype: int64

# %%
lignes_avec_na = df_global[df_global['Beds'].isna()]

print(lignes_avec_na)
# Out:
# Empty DataFrame
# Columns: [hospital, canton, delivery, year, cases_c-section, cases_kidney, Reg, Uni, percentage_c-section, to_delete, Doctor, Doctor_in_formation, Nurse, Other_Nurse, Total_staff, Operation_rooms, Delivery_rooms, Private_division, Beds]
# Index: []

# %%
na_per_variable = df_global.isna().sum()

# %%
# Save the DataFrame to a CSV file
df_global.to_csv('hospital_cases_GMA.csv', index=False)  # Use index=False to omit writing row numbers as index

# %%
df_global.columns
# Out:
# Index(['hospital', 'canton', 'delivery', 'year', 'cases_c-section',
#        'cases_kidney', 'Reg', 'Uni', 'percentage_c-section', 'to_delete',
#        'Doctor', 'Doctor_in_formation', 'Nurse', 'Other_Nurse', 'Total_staff',
#        'Operation_rooms', 'Delivery_rooms', 'Private_division', 'Beds'],
#       dtype='object')
