# %%
import pandas as pd

# %% [markdown]
# # Import c-section data

# %%
url_lst = ['https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE1.html',
      'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE2.html',
      'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE3.html',
      'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE4.html',
      'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDE5.html',
      'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDIw.html',
      'https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS40JTdDMCZxeT0yMDIx.html']

i=0
df_cesarienne = pd.DataFrame()

for year in range(2015, 2022):
    # Remplacez 'lien_annee' par le lien spécifique pour chaque année
    url = url_lst[i]
    
    # Utilisez pd.read_html() pour importer la table à partir du lien
    tables = pd.read_html(url)
    
    # Sélectionnez la table appropriée (peut nécessiter un examen préalable)
    df = tables[0]
    
    # Ajoutez une colonne 'year' avec l'année correspondante
    df['year'] = year
    
    # Ajoutez le DataFrame à la liste
    df_cesarienne = pd.concat([df_cesarienne, df], ignore_index=True)
    i+=1

# %% [markdown]
# # Import hospital data (number of doctors, nurses, ...)

# %%
url = "https://spitalstatistik.bagapps.ch/data/download/kzp21_KZ_TimeSerie.xlsx?v=1678279041"
sheet = 'KZ2008-KZ2021'
df_hopitaux = pd.read_excel(url, sheet_name=sheet)

#Description des paramètres: 
# https://spitalstatistik.bagapps.ch/data/download/kzp21_description_fr.pdf?v=1678279036

# %%
df_hopitaux = df_hopitaux[df_hopitaux['JAHR']>2014]

# %%
df_hopitaux
# Out:
#       JAHR  KT Status                                               Inst  \
# 2108  2015  AG    NaN                             Kantonsspital Aarau AG
# 2109  2015  AG    NaN                             Kantonsspital Baden AG
# 2110  2015  AG    NaN                            Hirslanden Klinik Aarau
# 2111  2015  AG    NaN                        Gesundheitszentrum Fricktal
# 2112  2015  AG    NaN                        Kreisspital für das Freiamt
# ...    ...  ..    ...                                                ...
# 4069  2021  ZH    NaN                                Geburtshaus Delphys
# 4070  2021  ZH    NaN  Universitäts-Kinderspital Zürich - Das Spital ...
# 4071  2021  ZH    NaN                                    Klinik Lengg AG
# 4072  2021  ZH    NaN                                   Klinik Susenberg
# 4073  2021  ZH    NaN                                          Sune-Egge
#
#                       Adr               Ort   Typ Notfalldienst  \
# 2108       Tellstrasse 15        5000 Aarau  K112           NaN
# 2109             Im Ergel        5404 Baden  K112           NaN
# 2110         Schänisweg 1        5000 Aarau  K112           NaN
# 2111   Riburgerstrasse 12  4310 Rheinfelden  K121           NaN
# 2112    Spitalstrasse 144      5630 Muri AG  K121           NaN
# ...                   ...               ...   ...           ...
# 4069   Badenerstrasse 177       8003 Zürich  K232           NaN
# 4070  Steinwiesstrasse 75       8032 Zürich  K233           NaN
# 4071    Bleulerstrasse 60       8008 Zürich  K235           NaN
# 4072        Schreberweg 9       8044 Zürich  K235           NaN
# 4073     Konradstrasse 62       8005 Zürich  K235           NaN
#
#      Infrastruktur1 Infrastruktur2  ... ErlOKPAmbB ErlStatB ErlKVGStatB  \
# 2108            NaN            NaN  ...        NaN      NaN         NaN
# 2109            NaN            NaN  ...        NaN      NaN         NaN
# 2110            NaN            NaN  ...        NaN      NaN         NaN
# 2111            NaN            NaN  ...        NaN      NaN         NaN
# 2112            NaN            NaN  ...        NaN      NaN         NaN
# ...             ...            ...  ...        ...      ...         ...
# 4069            NaN            NaN  ...   334453.0      NaN   2097414.0
# 4070            NaN            NaN  ...        NaN      NaN         NaN
# 4071            NaN            NaN  ...        NaN      NaN         NaN
# 4072            NaN            NaN  ...        NaN      NaN         NaN
# 4073            NaN            NaN  ...        NaN      NaN         NaN
#
#      ErlKVGStatVB ErlZvOKPStatB ErlZvOKPStatVB  ErlLangB PTageLang AustLang  \
# 2108          NaN           NaN            NaN       NaN       NaN      NaN
# 2109          NaN           NaN            NaN       NaN       NaN      NaN
# 2110          NaN           NaN            NaN       NaN       NaN      NaN
# 2111          NaN           NaN            NaN       NaN       NaN      NaN
# 2112          NaN           NaN            NaN       NaN       NaN      NaN
# ...           ...           ...            ...       ...       ...      ...
# 4069    45.000033           0.0            NaN       NaN       0.0      0.0
# 4070          NaN           NaN            NaN       NaN       0.0      0.0
# 4071          NaN           NaN            NaN       NaN       0.0      0.0
# 4072          NaN           NaN            NaN       NaN       0.0      0.0
# 4073          NaN           NaN            NaN       NaN       0.0      0.0
#
#      KostLangT
# 2108       NaN
# 2109       NaN
# 2110       NaN
# 2111       NaN
# 2112       NaN
# ...        ...
# 4069       0.0
# 4070       0.0
# 4071       0.0
# 4072       0.0
# 4073       0.0
#
# [1966 rows x 216 columns]

# %% [markdown]
# Create a variable if it is an university hospital

# %%
nom_hopitaux = ['Les Hôpitaux Universitaires de Genève HUG',
                'CHUV Centre Hospitalier Universitaire Vaudois',
                'Inselspital Bern','Insel Gruppe AG (universitär)',
                'Universitätsspital Zürich',
                'Universitätsspital Basel',
               'UniversitÃ¤tsspital ZÃ¼rich',
               'CHUV Centre Hospitalier Universitaire Vaudois',
               'UniversitÃ¤tsspital Basel',
                'Les HÃ´pitaux Universitaires de GenÃ¨ve HUG',
                'Insel Gruppe AG (universitÃ¤r)']

df_hopitaux['Uni'] = df_hopitaux['Inst'].apply(lambda x: 1 if x in nom_hopitaux else 0)

#df_hopitaux = df_hopitaux[df_hopitaux['Inst'].isin(nom_hopitaux)]

# %% [markdown]
# Create a variable is it is a canton Romand or Swiss Allemand

# %%
Canton_RO = ['GE','VD','NE','JU','FR','VS','TI']
df_hopitaux['Reg'] = df_hopitaux['KT'].apply(lambda x: 'RO' if x in Canton_RO else 'AL')

# %%
columns = ['JAHR','KT','Inst','PersA','PersAWB','PersP','PersMT','PersT','Ops','Gebs','pPatLKP']

df_hopitaux = df_hopitaux[columns]

df_hopitaux['Inst'] = df_hopitaux['Inst'].replace('Inselspital Bern', 'Insel Gruppe AG (universitär)')

columns = ['JAHR','KT','Inst','Doctor','Doctor_in_formation','Nurse','Other_Nurse','Total_staff','Operation_rooms','Delivery_rooms','Private_division']
# Out:
# /var/folders/2n/hcnm2b7x4ms7q2k734nx80p80000gn/T/ipykernel_3802/2392983586.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hopitaux['Inst'] = df_hopitaux['Inst'].replace('Inselspital Bern', 'Insel Gruppe AG (universitär)')

# %%
df_hopitaux.columns = columns

# %% [markdown]
# # Import kidney transplatations data

# %%
# L.5.1.F   Total des transplantations rénales
data_2015 ="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE1.html"
data_2016="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE2.html"
data_2017="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE3.html"
data_2018="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE4.html"
data_2019="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDE5.html"
data_2020="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDIw.html"
data_2021="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NsNS4xJTdDMCZxeT0yMDIx.html"


tables = pd.read_html(data_2015)
df_2015_kidney = tables[0]
df_2015_kidney['year'] = 2015

tables = pd.read_html(data_2016)
df_2016_kidney = tables[0]
df_2016_kidney['year'] = 2016

tables = pd.read_html(data_2017)
df_2017_kidney = tables[0]
df_2017_kidney['year'] = 2017

tables = pd.read_html(data_2018)
df_2018_kidney = tables[0]
df_2018_kidney['year'] = 2018

tables = pd.read_html(data_2019)
df_2019_kidney = tables[0]
df_2019_kidney['year'] = 2019

tables = pd.read_html(data_2020)
df_2020_kidney = tables[0]
df_2020_kidney['year'] = 2020

tables = pd.read_html(data_2021)
df_2021_kidney = tables[0]
df_2021_kidney['year'] = 2021

# %%
# Ajoutez le DataFrame à la liste
kidney = pd.concat([df_2015_kidney,df_2016_kidney,df_2017_kidney,df_2018_kidney,df_2019_kidney,df_2020_kidney,df_2021_kidney], ignore_index=True)

# %%
kidney = kidney[kidney['canton'] != 'canton']

# %% [markdown]
# # Import delivery data

# %%
# G.1.1.F   Accouchements hospitaliers
link = "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE1.html"
tables = pd.read_html(link)
df_2015 = tables[0]
df_2015.head()
df_2015['year'] = 2015
df_2015.head()


data_2016 = "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE2.html"
data_2017 = "https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE3.html"
data_2018 ="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE4.html"
data_2019 ="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDE5.html"
data_2020 ="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDIw.html"
data_2021 ="https://www.bag.admin.ch/bag/fr/home/zahlen-und-statistiken/zahlen-fakten-zu-spitaelern/qualitaetsindikatoren-der-schweizer-akutspitaeler/qualitaetsindikatoren-fallzahl.exturl.html/aHR0cHM6Ly9zcGl0YWxzdGF0aXN0aWsuYmFnYXBwcy5jaC9wb3/J0YWxfZnIucGhwP3A9cWlmYWxseiZsYW5nPWZyJmJhc2tldD0l/N0NnMS4xJTdDMCZxeT0yMDIx.html"

tables = pd.read_html(data_2016)
df_2016 = tables[0]
df_2016['year'] = 2016

tables = pd.read_html(data_2017)
df_2017 = tables[0]
df_2017['year'] = 2017

tables = pd.read_html(data_2018)
df_2018 = tables[0]
df_2018['year'] = 2018

tables = pd.read_html(data_2019)
df_2019 = tables[0]
df_2019['year'] = 2019

tables = pd.read_html(data_2020)
df_2020 = tables[0]
df_2020['year'] = 2020

tables = pd.read_html(data_2021)
df_2021 = tables[0]
df_2021['year'] = 2021

accouchement = pd.concat([df_2015,df_2016,df_2017,df_2018,df_2019,df_2020,df_2021], ignore_index=True)

# %% [markdown]
# # Merge and filter the dataframes

# %%
#Renommer les titres des colonnes pour avoir les mêmes partout et éviter les caractères spéciaux
kidney.rename(columns={'hÃ´pital': 'hospital', 'nombre de cas':'cases_kidney'}, inplace=True)
df_cesarienne.rename(columns={'hÃ´pital': 'hospital', 'nombre de cas':'cases_c-section'}, inplace=True)
accouchement.rename(columns={'hÃ´pital': 'hospital', 'nombre de cas':'delivery'}, inplace=True)

# %%
#Merger les df en fonction de year, hospital et canton

df_global = accouchement.merge(df_cesarienne, on=['year', 'hospital','canton'], how='left')
df_global = df_global.merge(kidney, on=['year', 'hospital','canton'], how='left')
df_global = df_global[df_global['canton'] != 'canton']

# %%
#df_global['hospital'] = df_global['hospital'].replace('UniversitÃ¤tsspital ZÃ¼rich', 'ZH')
#df_global['hospital'] = df_global['hospital'].replace('CHUV Centre Hospitalier Universitaire Vaudois', 'VD')
#df_global['hospital'] = df_global['hospital'].replace('UniversitÃ¤tsspital Basel', 'BS')
#df_global['hospital'] = df_global['hospital'].replace('Les HÃ´pitaux Universitaires de GenÃ¨ve HUG', 'GE')
#df_global['hospital'] = df_global['hospital'].replace('Insel Gruppe AG (universitÃ¤r)', 'BE')

# %%
#hospital_to_keep = ['ZH','VD','BS','GE','BE']
#df_global = df_global[df_global['hospital'].isin(hospital_to_keep)]

# %%
df_hopitaux.rename(columns={'JAHR': 'year'}, inplace=True)
#df_hopitaux.rename(columns={'KT': 'hospital','JAHR': 'year'}, inplace=True)
# Out:
# /var/folders/2n/hcnm2b7x4ms7q2k734nx80p80000gn/T/ipykernel_3802/487221211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hopitaux.rename(columns={'JAHR': 'year'}, inplace=True)

# %%
df_global['Reg'] = df_global['canton'].apply(lambda x: 'RO' if x in Canton_RO else 'AL')
df_global['Uni'] = df_global['hospital'].apply(lambda x: 1 if x in nom_hopitaux else 0)

# %%
df_global
# Out:
#                                               hospital canton delivery  year  \
# 0          Les HÃ´pitaux Universitaires de GenÃ¨ve HUG     GE    4 048  2015
# 1                               LUKS Spitalbetriebe AG     LU    2 988  2015
# 2        CHUV Centre Hospitalier Universitaire Vaudois     VD    2 909  2015
# 3                          UniversitÃ¤tsspital ZÃ¼rich     ZH    2 839  2015
# 4                            UniversitÃ¤tsspital Basel     BS    2 509  2015
# ..                                                 ...    ...      ...   ...
# 703                           Geburtshaus Tagmond GmbH     BL       43  2021
# 704  Center da Sanda Engiadina Bassa Ospidal d'Engi...     GR       41  2021
# 705                   Maison de naissance Les Cigognes     JU       35  2021
# 706                    Maison de Naissance Tilia SÃ rl     NE       32  2021
# 707                           Asana Spital Menziken AG     AG        1  2021
#
#     cases_c-section cases_kidney Reg  Uni
# 0             1 196           35  RO    1
# 1               982          NaN  AL    0
# 2               963           52  RO    1
# 3             1 226           83  AL    1
# 4               912           80  AL    1
# ..              ...          ...  ..  ...
# 703             NaN          NaN  AL    0
# 704              14          NaN  AL    0
# 705             NaN          NaN  RO    0
# 706             NaN          NaN  RO    0
# 707             NaN          NaN  AL    0
#
# [702 rows x 8 columns]

# %%
#df_global = df_global.merge(df_hopitaux, on=['year', 'hospital'], how='left')
#df_global = df_global.drop(columns=['canton'])

# %%
df_global['delivery'] = df_global['delivery'].apply(lambda x: x.replace('\xa0', ''))
df_global['delivery'] = pd.to_numeric(df_global['delivery'], errors='coerce')

df_global['cases_c-section'] = df_global['cases_c-section'].apply(lambda x: x.replace('\xa0', '') if isinstance(x, str) else x)
df_global['cases_c-section'] = pd.to_numeric(df_global['cases_c-section'], errors='coerce')

df_global['cases_kidney'] = df_global['cases_kidney'].apply(lambda x: x.replace('\xa0', '') if isinstance(x, str) else x)
df_global['cases_kidney'] = pd.to_numeric(df_global['cases_kidney'], errors='coerce')

# %%
# Use a lambda function to conditionally divide values by 100
#df_global['Private_division'] = df_global['Private_division'].apply(lambda x: x / 100 if x > 1 else x)

# %%
df_global['percentage_c-section'] = df_global['cases_c-section']/df_global['delivery']

# %%
# Save the DataFrame to a CSV file
df_global.to_csv('hospital_cases.csv', index=False)  # Use index=False to omit writing row numbers as index

# %%
df_global
# Out:
#                                               hospital canton  delivery  year  \
# 0          Les HÃ´pitaux Universitaires de GenÃ¨ve HUG     GE      4048  2015
# 1                               LUKS Spitalbetriebe AG     LU      2988  2015
# 2        CHUV Centre Hospitalier Universitaire Vaudois     VD      2909  2015
# 3                          UniversitÃ¤tsspital ZÃ¼rich     ZH      2839  2015
# 4                            UniversitÃ¤tsspital Basel     BS      2509  2015
# ..                                                 ...    ...       ...   ...
# 703                           Geburtshaus Tagmond GmbH     BL        43  2021
# 704  Center da Sanda Engiadina Bassa Ospidal d'Engi...     GR        41  2021
# 705                   Maison de naissance Les Cigognes     JU        35  2021
# 706                    Maison de Naissance Tilia SÃ rl     NE        32  2021
# 707                           Asana Spital Menziken AG     AG         1  2021
#
#      cases_c-section  cases_kidney Reg  Uni  percentage_c-section
# 0             1196.0          35.0  RO    1              0.295455
# 1              982.0           NaN  AL    0              0.328648
# 2              963.0          52.0  RO    1              0.331042
# 3             1226.0          83.0  AL    1              0.431842
# 4              912.0          80.0  AL    1              0.363491
# ..               ...           ...  ..  ...                   ...
# 703              NaN           NaN  AL    0                   NaN
# 704             14.0           NaN  AL    0              0.341463
# 705              NaN           NaN  RO    0                   NaN
# 706              NaN           NaN  RO    0                   NaN
# 707              NaN           NaN  AL    0                   NaN
#
# [702 rows x 9 columns]
