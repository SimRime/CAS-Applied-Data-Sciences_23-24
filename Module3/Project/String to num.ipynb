# %%
# Tranform string variables into numerical variables:
cleanup_nums = {'Akt':      {'A': 0, 'A, R': 1, 'A, P, R' : 2, 'A, P':3 },
                  'SL': {'nan':0,'NF':1, 'NF, IPS': 2, 'IPS':3 },
                  'Typ':       {'K122':0, 'K111': 1, 'K123': 2,'K121':3, 'K112':4, 'K232':5, 'K231':6 },
                  'LA':    {'Amb, Stat':0},
                  'WB':   {'nan':0, 'BGs':1, 'Arzt, BGs':2, 'MSt, Arzt, BGs':3, 'MSt, BGs':4},
                  'KT':   {'ZG':0, 'BS':1, 'VD':2, 'GR':3, 'TI':4, 'GE':5, 'ZH':6, 'AG':7, 'FR':8, 'BE':9, 'LU':10,
                          'SG':11, 'JU':12, 'BL':13, 'GL':14, 'NW':15, 'OW':16, 'UR':17, 'SO':18, 'SZ':19, 'TG':20, 'VS':21,
                          'SH':22, 'NE':23, 'AR':24},
                  'RForm':   {'R1':0, 'R4':1, 'R2':2},
                  'SA':   {'nan':0, 'MRI, CT':1, 'MRI, CT, Dia':2, 'MRI, CT, PET, CC, LB, Angio, Dia':3, 'CT':4,
                           'MRI, CT, Lito, Angio':5, 'MRI, CT, PET, CC, Angio':6, 'MRI, CT, Angio, Dia':7,
                           'MRI, CT, PET, CC, LB, Lito, Angio, Dia':8, 'MRI, CT, Angio':9, 'MRI, CT, CC, Lito, Angio, Dia':10,
                           'MRI, CT, LB, Angio, Dia':11, 'MRI, CT, CC, Angio':12, 'MRI, CT, PET, CC, Angio, Dia':13,
                           'MRI, CT, CC, LB, Lito, Angio, Dia':14, 'Lito':15, 'MRI, CT, PET, CC, LB, Dia':16,
                           'MRI, CT, PET, CC, Lito, Angio, Dia':17, 'CT, Dia':18, 'MRI, CT, Lito, Angio, Dia':19,
                           'Angio, Dia':20, 'MRI, CT, Lito, Dia':21, 'CT, CC, Lito, Angio, Dia':22,
                           'MRI, CT, CC, LB, Angio':23, 'Angio':24, 'MRI, CT, PET, CC, LB, Lito, Angio':25,
                           'MRI, CT, PET, CC, LB, Angio':26, 'CT, Angio, Dia':27, 'CT, CC, Angio, Dia':28,
                           'MRI, CT, LB, Lito, Angio':29, 'CT, Angio':30, 'MRI, CT, PET, Angio, Dia':31},
                     }

# %%
df.replace(cleanup_nums, inplace=True)
