# %% [markdown]
# # Decision Tree and Random Forest

# %%
from sklearn import linear_model
from sklearn import tree
from sklearn import ensemble
from sklearn.tree import DecisionTreeRegressor

from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import StandardScaler

# common visualization module
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
sns.set()

# numeric library
import numpy as np

import os
import pandas as pd
from time import time as timer
import tarfile

import tensorflow as tf

# %matplotlib inline
from matplotlib import animation
from IPython.display import HTML

# %%
#Import the two cleaned datasets
# dataset with the threshold
file_path = 'C:/Users/Gaëlle/Documents/_CAS applied data science/3. Module 3 Data analysis and machine learning/Project/Models/final_GMA.csv'
df = pd.read_csv(file_path)

# %%
column_names=df.columns.tolist()    
#column_names
# Out:
# ['c_section_rate',
#  'I.1.16.M',
#  'A.5.1.F',
#  'A.7.14.M',
#  'L.6.4.F',
#  'KostAWLFA',
#  'L.5.5.F',
#  'A.7.1.F',
#  'D.2.6.P',
#  'J.1.4.M',
#  'L.6.8.F',
#  'J.1.5.M',
#  'A.7.4.F',
#  'pPatLKP',
#  'KostKVGStatA',
#  'AnlKVGStatA',
#  'A.7.7.M',
#  'F.3.7.M',
#  'D.1.2.M',
#  'B.1.9.M',
#  'H.1.5.P',
#  'I.1.8.M',
#  'L.5.3.F',
#  'J.3.1.P',
#  'H.4.2.P',
#  'A.7.15.M',
#  'A.7.18.P',
#  'B.1.14.P',
#  'E.4.6.M',
#  'E.4.16.P',
#  'H.1.9.P',
#  'D.1.1.M',
#  'KostOKPAmbA',
#  'G.5.3.P',
#  'A.7.24.F',
#  'Gebs',
#  'A.7.28.M',
#  'AustStatMSA',
#  'F.3.3.M',
#  'A.3.2.V',
#  'F.1.4.F',
#  'A.7.13.M',
#  'I.1.9.M',
#  'G.2.2.F',
#  'H.1.7.M',
#  'E.4.2.M',
#  'StdBelA',
#  'E.5.4.F',
#  'H.3.2.F',
#  'E.3.1.F',
#  'A.1.14.P',
#  'L.6.1.F',
#  'E.4.15.M',
#  'A.7.11.V',
#  'I.2.7.M',
#  'KostAmbA',
#  'F.3.9.F',
#  'A.7.8.M',
#  'A.7.12.V',
#  'J.1.1.M',
#  'G.3.5.P',
#  'H.3.3.F',
#  'F.1.5.X',
#  'C.1.5.S',
#  'F.2.8.M',
#  'G.6.3.F',
#  'E.4.11.F',
#  'B.1.11.M',
#  'A.7.29.M',
#  'E.4.1.V',
#  'A.7.6.F',
#  'J.1.3.P',
#  'A.7.27.M',
#  'G.6.4.F',
#  'AustStatMST',
#  'I.1.18.M',
#  'D.4.5.M',
#  'G.4.4.M',
#  'F.2.10.M',
#  'I.1.19.M',
#  'I.2.16.F',
#  'KostZvOKPStatA',
#  'KostForLFA',
#  'D.1.4.M',
#  'H.2.1.F',
#  'G.3.7.P',
#  'E.3.5.F',
#  'ErlOKPAmbA',
#  'A.7.3.F',
#  'B.1.14.M',
#  'D.3.1.F',
#  'Ops',
#  'E.5.2.M',
#  'F.2.2.M',
#  'L.5.4.F',
#  'G.2.9.F',
#  'G.2.4.F',
#  'H.1.6.P',
#  'G.2.6.F',
#  'G.5.1.F',
#  'G.6.2.F',
#  'AwBesold',
#  'D.4.2.P',
#  'PersMT',
#  'I.1.24.X',
#  'FiErg',
#  'A.1.4.M',
#  'C.2.2.P',
#  'EtDef',
#  'E.1.1.X',
#  'D.1.10.M',
#  'G.1.3.P',
#  'H.1.10.M',
#  'A.7.2.F',
#  'AwSonst',
#  'A.7.23.M',
#  'B.1.1.M',
#  'G.2.7.F',
#  'F.2.6.M',
#  'A.2.3.M',
#  'A.3.6.F',
#  'G.2.5.F',
#  'A.1.12.X',
#  'A.2.5.M',
#  'A.7.7.V',
#  'F.2.3.M',
#  'E.3.3.F',
#  'G.2.8.F',
#  'F.3.2.M',
#  'A.1.1.M',
#  'E.4.1.M',
#  'D.2.6.M',
#  'D.2.1.M',
#  'pCT_AMB',
#  'E.4.3.M',
#  'D.2.5.M',
#  'H.3.5.M',
#  'I.4.1.F',
#  'I.1.22.M',
#  'B.3.2.M',
#  'G.4.3.F',
#  'B.1.15.X',
#  'A.7.11.M',
#  'J.2.1.M',
#  'ErlAmbStatLangA',
#  'L.5.6.F',
#  'C.1.2.P',
#  'I.1.20.M',
#  'A.7.12.M',
#  'F.4.1.M',
#  'I.1.21.M',
#  'B.1.18.M',
#  'E.1.2.P',
#  'L.5.1.F',
#  'E.5.5.M',
#  'A.3.5.P',
#  'A.4.1.F',
#  'E.2.2.M',
#  'G.2.3.F',
#  'D.4.3.M',
#  'A.7.17.M',
#  'F.2.11.M',
#  'A.1.9.P',
#  'L.1.2.F',
#  'L.6.2.F',
#  'F.5.2.F',
#  'L.3.2.F',
#  'D.2.3.M',
#  'L.3.1.F',
#  'G.1.1.P',
#  'ErlZvOKPStatA',
#  'pCT_STAT',
#  'F.3.8.F',
#  'D.1.3.M',
#  'F.2.5.M',
#  'A.1.1.V',
#  'A.5.2.F',
#  'I.2.5.M',
#  'G.4.6.M',
#  'L.2.2.F',
#  'JAHR',
#  'AnzStand',
#  'J.2.2.M',
#  'L.6.3.F',
#  'pPatWAU',
#  'CMIb',
#  'D.1.9.M',
#  'B.1.7.M',
#  'E.4.14.P',
#  'L.3.3.F',
#  'F.2.1.F',
#  'PersA',
#  'I.2.4.F',
#  'A.3.2.M',
#  'A.7.20.M',
#  'D.4.1.M',
#  'F.5.3.F',
#  'G.1.2.P',
#  'J.2.1.V',
#  'B.1.12.M',
#  'B.4.2.F',
#  'J.1.1.V',
#  'F.2.12.M',
#  'L.1.3.F',
#  'E.3.4.F',
#  'B.1.3.M',
#  'B.1.5.M',
#  'AmbKonsT',
#  'L.7.1.F',
#  'AwInvest',
#  'G.6.1.F',
#  'K.1.2.F',
#  'H.4.3.M',
#  'H.4.5.X',
#  'L.3.4.F',
#  'A.7.26.M',
#  'A.6.2.F',
#  'A.1.8.M',
#  'D.1.12.M',
#  'B.1.12.P',
#  'E.8.1.M',
#  'I.2.15.P',
#  'C.1.1.F',
#  'I.2.17.F',
#  'G.2.1.F',
#  'D.4.4.P',
#  'A.7.19.M',
#  'B.1.1.V',
#  'F.4.2.M',
#  'I.2.10.M',
#  'A.1.2.M',
#  'E.7.1.M',
#  'I.2.14.M',
#  'H.5.1.F',
#  'I.2.9.M',
#  'E.2.3.P',
#  'E.6.1.M',
#  'L.4.1.F',
#  'A.3.4.M',
#  'H.1.8.M',
#  'I.1.12.M',
#  'A.6.1.F',
#  'I.2.18.M',
#  'B.2.2.P',
#  'G.3.2.P',
#  'L.5.2.F',
#  'B.4.1.F',
#  'Z.1.1.X',
#  'H.2.2.P',
#  'PersAWB',
#  'B.1.16.P',
#  'PersP',
#  'B.3.1.F',
#  'A.1.3.M',
#  'ErlKVGStatA',
#  'E.4.5.M',
#  'B.1.4.M',
#  'A.2.2.M',
#  'H.3.1.F',
#  'G.3.1.X',
#  'I.1.11.P',
#  'B.5.1.F',
#  'G.3.4.P',
#  'A.3.4.V',
#  'E.5.6.M',
#  'EtSubv',
#  'G.3.1.M',
#  'H.3.4.P',
#  'D.2.4.M',
#  'E.2.4.P',
#  'D.1.8.V',
#  'H.1.5.M',
#  'B.1.10.M',
#  'F.3.4.M',
#  'A.1.17.P',
#  'G.5.2.F',
#  'D.1.6.M',
#  'D.1.8.M',
#  'K.1.1.F',
#  'F.3.1.M',
#  'G.3.3.P',
#  'J.2.4.M',
#  'F.2.4.F',
#  'A.3.1.F',
#  'CMIn',
#  'C.2.1.P',
#  'F.2.7.F',
#  'A.1.5.M',
#  'A.7.21.P',
#  'A.1.13.M',
#  'A.7.5.F',
#  'F.3.5.M',
#  'C.1.3.S',
#  'A.2.4.M',
#  'DADStatMSA',
#  'J.2.5.M',
#  'G.4.1.F',
#  'I.1.17.P',
#  'L.1.1.F',
#  'A.3.8.M',
#  'D.2.1.V',
#  'A.1.10.M',
#  'E.2.1.X',
#  'A.2.1.V',
#  'KostWBLFA',
#  'A.7.25.M',
#  'E.3.2.P',
#  'A.3.7.M',
#  'AwT',
#  'C.1.4.P',
#  'AmbKonsA',
#  'pMRI_AMB',
#  'A.1.7.M',
#  'E.4.15.P',
#  'E.1.1.M',
#  'J.1.2.S',
#  'E.2.1.M',
#  'NeugStatMST',
#  'E.4.8.M',
#  'G.4.2.F',
#  'B.1.2.M',
#  'I.1.14.M',
#  'PtageStatMSA',
#  'H.5.2.M',
#  'B.1.17.P',
#  'EtSonst',
#  'I.1.10.M',
#  'B.1.8.M',
#  'E.4.13.M',
#  'J.2.3.M',
#  'F.3.6.M',
#  'E.4.7.M',
#  'L.6.5.F',
#  'EtMedL',
#  'A.1.10.P',
#  'D.2.2.M',
#  'L.7.2.F',
#  'I.2.3.F',
#  'pMRI_STAT',
#  'E.4.12.F',
#  'A.2.1.M',
#  'B.1.18.P',
#  'G.4.5.F',
#  'L.2.1.F',
#  'G.1.1.F',
#  'A.2.6.P',
#  'B.1.7.V',
#  'A.7.16.M',
#  'A.1.15.P',
#  'A.3.5.M',
#  'I.1.8.V',
#  'E.5.3.M',
#  'D.4.2.M',
#  'E.4.4.M',
#  'I.1.15.M',
#  'D.1.13.M',
#  'A.7.10.M',
#  'pPatHOK',
#  'A.1.16.P',
#  'I.2.8.M',
#  'PtageStatMST',
#  'B.1.13.M',
#  'pPatWAK',
#  'AnlZvOKPStatA',
#  'J.1.6.M',
#  'D.1.7.M',
#  'B.1.9.P',
#  'F.6.1.F',
#  'E.5.1.F',
#  'PersT',
#  'I.1.23.X',
#  'I.2.13.M',
#  'H.3.6.M',
#  'D.1.5.M',
#  'A.7.9.M',
#  'A.7.22.P',
#  'F.2.13.V',
#  'A.1.11.M',
#  'KostStatA',
#  'K.1.3.F',
#  'D.1.11.M',
#  'H.4.4.M',
#  'I.1.13.M',
#  'E.4.16.M',
#  'StdBelP',
#  'F.3.1.V',
#  'pBettenBelStatA_new',
#  'ErlKVGStatVA_new',
#  'ErlZvOKPStatVA_new',
#  'threshold',
#  'Akt_A',
#  'Akt_A, P',
#  'Akt_A, P, R',
#  'Akt_A, R',
#  'SL_IPS',
#  'SL_NF',
#  'SL_NF, IPS',
#  'Typ_K111',
#  'Typ_K112',
#  'Typ_K121',
#  'Typ_K122',
#  'Typ_K123',
#  'Typ_K231',
#  'Typ_K232',
#  'LA_Amb, Stat',
#  'WB_Arzt, BGs',
#  'WB_BGs',
#  'WB_MSt, Arzt, BGs',
#  'WB_MSt, BGs',
#  'KT_AG',
#  'KT_AR',
#  'KT_BE',
#  'KT_BL',
#  'KT_BS',
#  'KT_FR',
#  'KT_GE',
#  'KT_GL',
#  'KT_GR',
#  'KT_JU',
#  'KT_LU',
#  'KT_NE',
#  'KT_NW',
#  'KT_OW',
#  'KT_SG',
#  'KT_SH',
#  'KT_SO',
#  'KT_SZ',
#  'KT_TG',
#  'KT_TI',
#  'KT_UR',
#  'KT_VD',
#  'KT_VS',
#  'KT_ZG',
#  'KT_ZH',
#  'RForm_R1',
#  'RForm_R2',
#  'RForm_R4',
#  'SA_Angio',
#  'SA_Angio, Dia',
#  'SA_CT',
#  'SA_CT, Angio',
#  'SA_CT, Angio, Dia',
#  'SA_CT, CC, Angio, Dia',
#  'SA_CT, CC, Lito, Angio, Dia',
#  'SA_CT, Dia',
#  'SA_Lito',
#  'SA_MRI, CT',
#  'SA_MRI, CT, Angio',
#  'SA_MRI, CT, Angio, Dia',
#  'SA_MRI, CT, CC, Angio',
#  'SA_MRI, CT, CC, LB, Angio',
#  'SA_MRI, CT, CC, LB, Lito, Angio, Dia',
#  'SA_MRI, CT, CC, Lito, Angio, Dia',
#  'SA_MRI, CT, Dia',
#  'SA_MRI, CT, LB, Angio, Dia',
#  'SA_MRI, CT, LB, Lito, Angio',
#  'SA_MRI, CT, Lito, Angio',
#  'SA_MRI, CT, Lito, Angio, Dia',
#  'SA_MRI, CT, Lito, Dia',
#  'SA_MRI, CT, PET, Angio, Dia',
#  'SA_MRI, CT, PET, CC, Angio',
#  'SA_MRI, CT, PET, CC, Angio, Dia',
#  'SA_MRI, CT, PET, CC, LB, Angio',
#  'SA_MRI, CT, PET, CC, LB, Angio, Dia',
#  'SA_MRI, CT, PET, CC, LB, Dia',
#  'SA_MRI, CT, PET, CC, LB, Lito, Angio',
#  'SA_MRI, CT, PET, CC, LB, Lito, Angio, Dia',
#  'SA_MRI, CT, PET, CC, Lito, Angio, Dia']

# %% [markdown]
# ## Use dataset with the c-section rate

# %% [markdown]
# ## Creation of the X, Y, train and test

# %%
# Creation of the dependant variable
target_field = 'c_section_rate'
Y = df[target_field].copy()

# %%
# Set of independant variables
X = df.drop(columns=['c_section_rate','threshold']) # I delete threshold because we are using c-section rate

# %%
X.shape
# Out:
# (298, 466)

# %%
x = X.to_numpy().astype(np.float32)
y = Y.to_numpy().astype(np.float32)

# %%
# train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## Decision Tree

# %%
### Identify the max_depth

# List of max_depth values to test
max_depth_values = [5, 10, 15, 20, 25, 30, 40, 50, 60, 70, 80, 90, 100]

# Lists to store results
max_depth_list = []
mse_list = []

# Loop through max_depth values
for max_depth in max_depth_values:
    # Create and train the Decision Tree model
    dt = DecisionTreeRegressor(max_depth=max_depth)
    dt.fit(x_train, y_train)
    
    # Make predictions on the test set
    y_pred = dt.predict(x_test)
    
    # Calculate the MSE
    mse = mean_squared_error(y_test, y_pred)
    
    # Append results to lists
    max_depth_list.append(max_depth)
    mse_list.append(mse)

# Plot the results
plt.figure(figsize=(8, 6))
plt.plot(max_depth_list, mse_list, marker='o')
plt.title('Mean Squared Error vs. max_depth')
plt.xlabel('max_depth')
plt.ylabel('Mean Squared Error')
plt.grid(True)
plt.show()

# %% [markdown]
# It looks like max_depth 30 gives the lowest mse

# %%
# Entraînement du modèle
dt_model.fit(x_train, y_train)

# Prédiction sur l'ensemble de test
predictions = dt_model.predict(x_test)

# Évaluation du modèle
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predictions)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 0.00228726272172944

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
# Visualisation de l'arbre
plt.figure(figsize=(30, 8))
plot_tree(dt_model, filled=True, feature_names=X.columns)

plt.show()

# %%
# Visualization of feature importance
feature_importance = dt_model.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Select the top 50 most important features
top_50_features = feature_importance_df.head(50)

# Create a second figure for the visualization of the top 50 feature importance
plt.figure(figsize=(15, 6))
plt.bar(top_50_features['Feature'], top_50_features['Importance'], color='skyblue')
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Top 50 Feature Importance')
plt.xticks(rotation=45, ha='right')  # Rotate feature names for better readability
plt.show()

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### Fit the model

# %%
max_depth=30
n_est=50
rfc = ensemble.RandomForestRegressor(max_depth=max_depth, n_estimators=n_est,)
rfc.fit(x_train, y_train)
yy_test = rfc.predict(x_test)
yy_train = rfc.predict(x_train)
print("training score : %.3f (max_depth=%d, n_est=%d)" % (rfc.score(x_train, y_train), max_depth, n_est))
print("test score : %.3f (max_depth=%d, n_est=%d)" % (rfc.score(x_test, y_test), max_depth, n_est))
# Out:
# training score : 0.949 (max_depth=30, n_est=50)
# test score : 0.740 (max_depth=30, n_est=50)

# %%
# How does it compare to linear model? Can you make a plot of y_pred vs y_exact as you did for a linear model and compare visually ?
plt.figure(figsize=(5,5))

plt.scatter(y_test, yy_test, label='test', marker='*',  c='red')
plt.scatter(y_train, yy_train, label='train', marker='x',c='blue')
plt.plot([0], [0], 'w.')  # dummy to show the origin

plt.xlabel("y_test and y_train")
plt.ylabel("predicted y_train and predicted y_test")
plt.gca().set_aspect('equal')#optional

plt.legend()

plt.show()

p

# %% [markdown]
# ### Feature importance

# %%
#### GMA
# Visualization of feature importance
feature_importance = rfc.feature_importances_
feature_importance_rfc = pd.DataFrame({'Feature': X.columns, 'Importance': feature_importance})
feature_importance_rfc = feature_importance_rfc.sort_values(by='Importance', ascending=False)

# Select the top 50 most important features
top_50_features = feature_importance_rfc.head(50)

# Create a second figure for the visualization of the top 50 features importance
plt.figure(figsize=(15, 6))
plt.bar(top_50_features['Feature'], top_50_features['Importance'], color='skyblue')
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Top 50 Feature Importance')
plt.xticks(rotation=45, ha='right')  # Rotate feature names for better readability
plt.show()
